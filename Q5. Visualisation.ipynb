# %%
import pandas as pd

# %%
#load the csv file of dataset into dataframe
f1=pd.read_csv(r"C:\Users\Lavannya\Documents\BI-Project\Data\Data.csv")
f1
# Out:
#        STATE            DISTRICT          TEH_NAME          BLOCK_NAME  \
# 0         AP           Anantapur            Biknur         Atmakur_atp
# 1         AP           Anantapur        Dich Palle               Gooty
# 2         AP           Anantapur    Sadashivanagar           Anantapur
# 3         AP           Anantapur        Bommanahal          Bommanahal
# 4         AP           Anantapur       Vidapanakal         Vidapanakal
# 5         AP           Anantapur        Yellareddy        Battalapalle
# 6         AP           Anantapur          Balkonda        Chilamathuru
# 7         AP           Anantapur          Balkonda        Chilamathuru
# 8         AP           Anantapur         Bichkunda         Bukkapatnam
# 9         AP           Anantapur        Machareddy    Chennakothapalle
# 10        AP           Anantapur            Mortad            Hindupur
# 11        AP           Anantapur             Varni           Penukonda
# ...

# %%
#creating the new attribute POM_Recharge
f1['POM_Recharge'] = (f1['MONSOON']).astype(float) - (f1['PREMON']).astype(float)

#print the updated dataframe
f1
# Out:
#        STATE            DISTRICT          TEH_NAME          BLOCK_NAME  \
# 0         AP           Anantapur            Biknur         Atmakur_atp
# 1         AP           Anantapur        Dich Palle               Gooty
# 2         AP           Anantapur    Sadashivanagar           Anantapur
# 3         AP           Anantapur        Bommanahal          Bommanahal
# 4         AP           Anantapur       Vidapanakal         Vidapanakal
# 5         AP           Anantapur        Yellareddy        Battalapalle
# 6         AP           Anantapur          Balkonda        Chilamathuru
# 7         AP           Anantapur          Balkonda        Chilamathuru
# 8         AP           Anantapur         Bichkunda         Bukkapatnam
# 9         AP           Anantapur        Machareddy    Chennakothapalle
# 10        AP           Anantapur            Mortad            Hindupur
# 11        AP           Anantapur             Varni           Penukonda
# ...

# %%
f1.to_csv(r"C:\Users\Lavannya\Documents\BI-Project\Data\PostComputationData.csv",index=False,encoding='utf-8-sig')

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
import matplotlib.pyplot as plt

y=f1.POM_Recharge
plt.ylabel('POM_Recharge')
plt.title('Degree of Groundwater Replenishment due to monsoon')
plt.xlabel('Years')
plt.tight_layout()
plt.show()
